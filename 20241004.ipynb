# %%
from pandas import DataFrame

data = {
    "종목명": ["3R", "3SOFT", "ACTS"],
    "현재가": [1510, 1790, 1185],
    "등락률": [7.36, 1.65, 1.28],
}

df = DataFrame(data, index=["037730", "036360", "005760"])
df
# Out:
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28

# %%
df.to_csv("abc/today_stock.csv", index=False)

# %%
df.to_excel("abc/today_stock.xlsx", index=False)

# %%
#실행할떄
